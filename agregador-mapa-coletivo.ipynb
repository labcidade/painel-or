# %%
import pandas as pd

# %%
sheet_id = '1cxla1UpAe1QXMeuCKQU9IHV351y15pCOoYeZ3NYQD90'
sheet_name = 'Página2'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
df_remocoes = pd.read_csv(url, nrows=1)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# c:\Users\labci\Documents\Git\GitHub\painel-or\agregador-mapa-coletivo.ipynb Célula 2 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/labci/Documents/Git/GitHub/painel-or/agregador-mapa-coletivo.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> sheet_name = 'Página2'
#       <a href='vscode-notebook-cell:/c%3A/Users/labci/Documents/Git/GitHub/painel-or/agregador-mapa-coletivo.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/labci/Documents/Git/GitHub/painel-or/agregador-mapa-coletivo.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> df_remocoes = pd.read_csv(url, nrows=1)
#
# ...

# %%
url
# Out:
# 'https://docs.google.com/spreadsheets/d/1cxla1UpAe1QXMeuCKQU9IHV351y15pCOoYeZ3NYQD90/gviz/tq?tqx=out:csv&sheet=Página1'

# %%
df_remocoes
